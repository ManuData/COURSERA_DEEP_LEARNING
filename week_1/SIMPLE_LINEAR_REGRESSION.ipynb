# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# EJEMPLO UOC
# EJERCICIO 1: 
semana = [3,5,2,8,6,9,3,4]
ganancia_velocidad = [87,119,47,195,162,234,72,110]

df = pd.DataFrame({'numero_semanas':semana,'ganancia_velocidad':ganancia_velocidad})
df = df.sort_values(by='numero_semanas')
df
# Out:
#    numero_semanas  ganancia_velocidad
# 2               2                  47
# 0               3                  87
# 6               3                  72
# 7               4                 110
# 1               5                 119
# 4               6                 162
# 3               8                 195
# 5               9                 234

# %%
plt.scatter(df.numero_semanas, df.ganancia_velocidad,  color='black')

# %%
np.array(df.numero_semanas.sort_values()).reshape(-1,1)
# Out:
# array([[2],
#        [3],
#        [3],
#        [4],
#        [5],
#        [6],
#        [8],
#        [9]])

# %%
# Create linear regression object
regr = linear_model.LinearRegression()
# Train the model using the training sets
regr.fit(np.array(df.numero_semanas).reshape(-1,1), np.array(df.ganancia_velocidad).reshape(-1,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Make predictions using the testing set
diabetes_y_pred = regr.predict(np.array(df.numero_semanas).reshape(-1,1))

# %%
# Plot outputs
plt.scatter(np.array(df.numero_semanas).reshape(-1,1), np.array(df.ganancia_velocidad).reshape(-1,1),  color='black')
plt.plot(np.array(df.numero_semanas).reshape(-1,1), np.array(df.ganancia_velocidad).reshape(-1,1), color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# %%
pd.DataFrame(diabetes_X) # Modificamos a DataFrame para poder tener más claridad para poder identificar la información.
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#             7         8         9
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
#https://stackoverflow.com/questions/18691084/what-does-1-mean-in-numpy-reshape
diabetes_X[:, np.newaxis, 2] # Estamos creando los inputs a partir de la columna 2
# Out:
# array([[ 0.06169621],
#        [-0.05147406],
#        [ 0.04445121],
#        [-0.01159501],
#        [-0.03638469],
#        [-0.04069594],
#        [-0.04716281],
#        [-0.00189471],
#        [ 0.06169621],
#        [ 0.03906215],
#        [-0.08380842],
#        [ 0.01750591],
#        [-0.02884001],
#        [-0.00189471],
#        [-0.02560657],
#        [-0.01806189],
#        [ 0.04229559],
#        [ 0.01211685],
#        [-0.0105172 ],
#        [-0.01806189],
#        [-0.05686312],
#        [-0.02237314],
#        [-0.00405033],
#        [ 0.06061839],
#        [ 0.03582872],
#        [-0.01267283],
#        [-0.07734155],
#        [ 0.05954058],
#        [-0.02129532],
#        [-0.00620595],
#        [ 0.04445121],
#        [-0.06548562],
#        [ 0.12528712],
#        [-0.05039625],
#        [-0.06332999],
#        [-0.03099563],
#        [ 0.02289497],
#        [ 0.01103904],
#        [ 0.07139652],
#        [ 0.01427248],
#        [-0.00836158],
# ...

# %%
# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
diabetes_X
